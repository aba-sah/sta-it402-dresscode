# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import sqlite3 as sq

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Loading data

# %% [markdown]
# #### Reading SQLite database - you will need to amend your path

# %%
# creating file path
dbfile = 'C:/Users/emitc/OneDrive/Documents/STA/Dresscode/sta-it402-dresscode/code/data/sqa-data-db.sqlite'

# Create a SQL connection to our SQLite database
conn = sq.connect(dbfile)

# %%
# creating cursor
cur = conn.cursor()

# reading all table names
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
# here is your table list
print(table_list)
# Out:
# [('school_rolls',), ('sqa_qualification_list',), ('sqa_data',), ('subject_groups',)]

# %%
df1 = pd.read_sql_query('SELECT * FROM school_rolls', conn)
df1.head()
# Out:
#      year  secondary_schools  secondary_pupils  base_year_census  \
# 0  1966.0                NaN          283592.0          316594.0
# 1  1967.0              665.0          288054.0          316594.0
# 2  1968.0              640.0          295625.0          316594.0
# 3  1969.0              616.0          307185.0          316594.0
# 4  1970.0              441.0          317027.0          316594.0
#
#    index_factor  predicted
# 0      0.895759          0
# 1      0.909853          0
# 2      0.933767          0
# 3      0.970281          0
# 4      1.001368          0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               56 non-null     float64
#  1   secondary_schools  54 non-null     float64
#  2   secondary_pupils   56 non-null     float64
#  3   base_year_census   56 non-null     float64
#  4   index_factor       56 non-null     float64
#  5   predicted          56 non-null     int64
# dtypes: float64(5), int64(1)
# memory usage: 2.8 KB

# %%
df2 = pd.read_sql_query('SELECT * FROM sqa_qualification_list', conn)
df2.head()
# Out:
#   QualificationId QualificationTitle SCQFLevel  SecondaryYear AdditionalYears  \
# 0          Higher             Higher         6            5.0               6
# 1  AdvancedHigher    Advanced Higher         7            6.0            None
# 2   OrdinaryGrade     Ordinary Grade         5            4.0             5;6
# 3       NewHigher         New Higher         6            5.0               6
# 4   StandardGrade     Standard Grade         5            4.0             5;6
#
#   DataStartYear DataEndYear
# 0          1986        None
# 1          2001        None
# 2          1986        1994
# 3     2000;2015   2002;2015
# 4          1986        2013

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   QualificationId     19 non-null     object
#  1   QualificationTitle  19 non-null     object
#  2   SCQFLevel           17 non-null     object
#  3   SecondaryYear       12 non-null     float64
#  4   AdditionalYears     6 non-null      object
#  5   DataStartYear       14 non-null     object
#  6   DataEndYear         6 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 1.2+ KB

# %%
df3 = pd.read_sql_query('SELECT * FROM sqa_data', conn)
df3.head()
# Out:
#   qualification  year                   Subject  NumberOfCentres gender  \
# 0          CSYS  1986  Art and Design (Enquiry)            127.0   male
# 1          CSYS  1986  Art and Design (Enquiry)            127.0   male
# 2          CSYS  1986  Art and Design (Enquiry)            127.0   male
# 3          CSYS  1986  Art and Design (Enquiry)            127.0   male
# 4          CSYS  1986  Art and Design (Enquiry)            127.0   male
#
#         grade  NoOfStudents
# 0     Entries          86.0
# 1  percentage           0.0
# 2           A           7.0
# 3           B          13.0
# 4           C          25.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159668 entries, 0 to 159667
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   qualification    159668 non-null  object
#  1   year             159668 non-null  object
#  2   Subject          159668 non-null  object
#  3   NumberOfCentres  118152 non-null  float64
#  4   gender           159668 non-null  object
#  5   grade            159668 non-null  object
#  6   NoOfStudents     133842 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 8.5+ MB

# %%
df4 = pd.read_sql_query('SELECT * FROM subject_groups', conn)
df4.head()
# Out:
#    Subject SubjectGroup CommonSubjectLabel qualification  year SubjectTaken  \
# 0  English      English            English     National3  2014          Yes
# 1  English      English            English     National3  2015          Yes
# 2  English      English            English     National3  2016          Yes
# 3  English      English            English     National3  2017          Yes
# 4  English      English            English     National3  2018          Yes
#
#    SCQFLevel
# 0          3
# 1          3
# 2          3
# 3          3
# 4          3

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6176 entries, 0 to 6175
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subject             6176 non-null   object
#  1   SubjectGroup        6176 non-null   object
#  2   CommonSubjectLabel  2582 non-null   object
#  3   qualification       6176 non-null   object
#  4   year                6176 non-null   int64
#  5   SubjectTaken        6176 non-null   object
#  6   SCQFLevel           6176 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 337.9+ KB

# %% [markdown]
# #### Finished reading SQLite database

# %% [markdown]
# ##### How many different grades are there?

# %%
df3['grade'].unique()
# Out:
# array(['Entries', 'percentage', 'A', 'B', 'C', 'D', 'E', 'Passes', '1',
#        '2', '3', '4', '5', '6', '7', 'Comp', 'COMP',
#        'PassesesInUngradedCourses', 'PassesUngraded',
#        'PassesUngradedCourses', 'A-C', 'Pass', 'Attainment', 'SCQF3',
#        'SCQF4', 'SCQF5', 'SCQF6', 'SCQF2', 'NoAward', 'A-B', 'A-D*',
#        'A-D'], dtype=object)

# %%
df3['grade'].nunique()
# Out:
# 32

# %% [markdown]
# #### Create and read in grade types table

# %%
df_grade_groups = pd.read_csv("grade_groups.csv")

# %%
df_grade_groups.head()
# Out:
#   grade grade_type
# 0     1  numerical
# 1     2  numerical
# 2     3  numerical
# 3     4  numerical
# 4     5  numerical

# %%
df_grade_groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grade       32 non-null     object
#  1   grade_type  32 non-null     object
# dtypes: object(2)
# memory usage: 640.0+ bytes

# %%
#conn = sqlite3.connect('cartoon_characters.db')
df_grade_groups.to_sql("grade_groups", conn, if_exists="replace") #need double quotes

# %%
# reading all table names
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
# here is your table list
print(table_list)
# Out:
# [('school_rolls',), ('sqa_qualification_list',), ('sqa_data',), ('subject_groups',), ('grade_groups',)]

# %%
# Be sure to close the connection
conn.close()

# %% [markdown]
# #### Join grade groups dataframe to grades dataframe

# %%
#df5 = df3.join(df_grade_groups, on=)
df5 = pd.merge(df3, df_grade_groups, on='grade')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159668 entries, 0 to 159667
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   qualification    159668 non-null  object
#  1   year             159668 non-null  object
#  2   Subject          159668 non-null  object
#  3   NumberOfCentres  118152 non-null  float64
#  4   gender           159668 non-null  object
#  5   grade            159668 non-null  object
#  6   NoOfStudents     133842 non-null  float64
#  7   grade_type       159668 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 11.0+ MB

# %%
#check that it has worked
df5.loc[(df5['grade_type'] == 'scqf')]
# Out:
#                    qualification  year                           Subject  \
# 143741       NationalCertificate  2014                        Accounting
# 143742       NationalCertificate  2014                        Accounting
# 143743       NationalCertificate  2014                        Accounting
# 143744       NationalCertificate  2014    Acting and Theatre Performance
# 143745       NationalCertificate  2014    Acting and Theatre Performance
# ...                          ...   ...                               ...
# 157164  NationalProgressionAward  2021           Web Design Fundamentals
# 157165  NationalProgressionAward  2021           Web Design Fundamentals
# 157166  NationalProgressionAward  2021  Zoo Animal Behaviour and Welfare
# 157167  NationalProgressionAward  2021  Zoo Animal Behaviour and Welfare
# 157168  NationalProgressionAward  2021  Zoo Animal Behaviour and Welfare
#
#         NumberOfCentres  gender  grade  NoOfStudents grade_type
# 143741              NaN    male  SCQF3           NaN       scqf
# 143742              NaN  female  SCQF3           NaN       scqf
# 143743              NaN     all  SCQF3           NaN       scqf
# 143744              NaN    male  SCQF3           NaN       scqf
# 143745              NaN  female  SCQF3           NaN       scqf
# ...                 ...     ...    ...           ...        ...
# 157164              NaN    male  SCQF2           NaN       scqf
# 157165              NaN  female  SCQF2           NaN       scqf
# 157166              NaN     all  SCQF2           NaN       scqf
# 157167              NaN    male  SCQF2           NaN       scqf
# 157168              NaN  female  SCQF2           NaN       scqf
#
# [13428 rows x 8 columns]

# %%
dummy = df5.loc[(df5['qualification'] == 'National5') & (df5['Subject'] == 'Urdu') & (df5['year'] == '2020')]

# %% [markdown]
# #### Sort the merged dataframe

# %%
df5 = df5.sort_values(by = ['qualification', 'year', 'Subject', 'gender', 'grade'])
df5.tail(40)
# Out:
#         qualification  year                Subject  NumberOfCentres  gender  \
# 126346  StandardGrade  2013  Technological Studies             79.0  female
# 129229  StandardGrade  2013  Technological Studies             79.0  female
# 132112  StandardGrade  2013  Technological Studies             79.0  female
# 17353   StandardGrade  2013  Technological Studies             79.0  female
# 34595   StandardGrade  2013  Technological Studies             79.0  female
# 109838  StandardGrade  2013  Technological Studies             79.0    male
# 113951  StandardGrade  2013  Technological Studies             79.0    male
# 118064  StandardGrade  2013  Technological Studies             79.0    male
# 122232  StandardGrade  2013  Technological Studies             79.0    male
# 126345  StandardGrade  2013  Technological Studies             79.0    male
# 129228  StandardGrade  2013  Technological Studies             79.0    male
# 132111  StandardGrade  2013  Technological Studies             79.0    male
# 17352   StandardGrade  2013  Technological Studies             79.0    male
# 34594   StandardGrade  2013  Technological Studies             79.0    male
# 109780  StandardGrade  2013                   Urdu             10.0     all
# 113893  StandardGrade  2013                   Urdu             10.0     all
# 118006  StandardGrade  2013                   Urdu             10.0     all
# 122174  StandardGrade  2013                   Urdu             10.0     all
# 126287  StandardGrade  2013                   Urdu             10.0     all
# 129170  StandardGrade  2013                   Urdu             10.0     all
# 132053  StandardGrade  2013                   Urdu             10.0     all
# 17294   StandardGrade  2013                   Urdu             10.0     all
# 109779  StandardGrade  2013                   Urdu             10.0  female
# 113892  StandardGrade  2013                   Urdu             10.0  female
# 118005  StandardGrade  2013                   Urdu             10.0  female
# 122173  StandardGrade  2013                   Urdu             10.0  female
# 126286  StandardGrade  2013                   Urdu             10.0  female
# 129169  StandardGrade  2013                   Urdu             10.0  female
# 132052  StandardGrade  2013                   Urdu             10.0  female
# 17293   StandardGrade  2013                   Urdu             10.0  female
# 34555   StandardGrade  2013                   Urdu             10.0  female
# 109778  StandardGrade  2013                   Urdu             10.0    male
# 113891  StandardGrade  2013                   Urdu             10.0    male
# 118004  StandardGrade  2013                   Urdu             10.0    male
# 122172  StandardGrade  2013                   Urdu             10.0    male
# 126285  StandardGrade  2013                   Urdu             10.0    male
# 129168  StandardGrade  2013                   Urdu             10.0    male
# 132051  StandardGrade  2013                   Urdu             10.0    male
# 17292   StandardGrade  2013                   Urdu             10.0    male
# 34554   StandardGrade  2013                   Urdu             10.0    male
#
#              grade  NoOfStudents  grade_type
# 126346           5           6.0   numerical
# 129229           6           2.0   numerical
# 132112           7           0.0   numerical
# 17353      Entries          76.0     entries
# 34595   percentage           6.0  percentage
# 109838           1         439.0   numerical
# 113951           2         299.0   numerical
# 118064           3         187.0   numerical
# 122232           4         143.0   numerical
# 126345           5          91.0   numerical
# 129228           6          48.0   numerical
# 132111           7           6.0   numerical
# 17352      Entries        1218.0     entries
# 34594   percentage          94.0  percentage
# 109780           1          60.0   numerical
# 113893           2          11.0   numerical
# 118006           3          19.0   numerical
# 122174           4           6.0   numerical
# 126287           5           6.0   numerical
# 129170           6           1.0   numerical
# 132053           7           NaN   numerical
# 17294      Entries         103.0     entries
# 109779           1          26.0   numerical
# 113892           2           4.0   numerical
# 118005           3           7.0   numerical
# 122173           4           1.0   numerical
# 126286           5           2.0   numerical
# 129169           6           0.0   numerical
# 132052           7           0.0   numerical
# 17293      Entries          40.0     entries
# 34555   percentage          39.0  percentage
# 109778           1          34.0   numerical
# 113891           2           7.0   numerical
# 118004           3          12.0   numerical
# 122172           4           5.0   numerical
# 126285           5           4.0   numerical
# 129168           6           1.0   numerical
# 132051           7           0.0   numerical
# 17292      Entries          63.0     entries
# 34554   percentage          61.0  percentage

# %% [markdown]
# ### Create a subroutine to deal with letter_groups

# %%
#no_change = ['Entries', 'A', 'B', 'C', 'NoAward', 'Pass', 'Passes']

def calculate_grades(x):
#    total = 0
    for i, v in x.iterrows():
#        total += v.
        if v.grade_type == 'letter_group': #and v.compare_previous != 0: #not a cumulation row
            print (v)          
    return x

# %%
df_em = df5.groupby(['qualification', 'year', 'Subject', 'gender']).apply(calculate_grades)
# Out:
# qualification      AdvancedHigher
# year                         2014
# Subject                Accounting
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   11
# grade_type           letter_group
# Name: 138367, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                Accounting
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                    8
# grade_type           letter_group
# Name: 138366, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Applied Mathematics
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                        86
# grade_type                letter_group
# Name: 138369, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Applied Mathematics
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                       197
# grade_type                letter_group
# Name: 138368, dtype: object
# qualification              AdvancedHigher
# year                                 2014
# Subject            Art and Design: Design
# NumberOfCentres                       NaN
# gender                             female
# grade                                 A-C
# NoOfStudents                          423
# grade_type                   letter_group
# Name: 138371, dtype: object
# qualification              AdvancedHigher
# year                                 2014
# Subject            Art and Design: Design
# NumberOfCentres                       NaN
# gender                               male
# grade                                 A-C
# NoOfStudents                           94
# grade_type                   letter_group
# Name: 138370, dtype: object
# qualification                  AdvancedHigher
# year                                     2014
# Subject            Art and Design: Expressive
# NumberOfCentres                           NaN
# gender                                 female
# grade                                     A-C
# NoOfStudents                              661
# grade_type                       letter_group
# Name: 138373, dtype: object
# qualification                  AdvancedHigher
# year                                     2014
# Subject            Art and Design: Expressive
# NumberOfCentres                           NaN
# gender                                   male
# grade                                     A-C
# NoOfStudents                              121
# grade_type                       letter_group
# Name: 138372, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Biology
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                 1248
# grade_type           letter_group
# Name: 138375, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Biology
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  590
# grade_type           letter_group
# Name: 138374, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Biology (Revised)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                       8
# grade_type              letter_group
# Name: 138377, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Biology (Revised)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                       5
# grade_type              letter_group
# Name: 138376, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Business Management
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                        90
# grade_type                letter_group
# Name: 138379, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Business Management
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                        54
# grade_type                letter_group
# Name: 138378, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Chemistry
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  995
# grade_type           letter_group
# Name: 138381, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Chemistry
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  839
# grade_type           letter_group
# Name: 138380, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Chemistry (Revised)
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                       124
# grade_type                letter_group
# Name: 138383, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Chemistry (Revised)
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                       115
# grade_type                letter_group
# Name: 138382, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Chinese Languages
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      12
# grade_type              letter_group
# Name: 138385, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Chinese Languages
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                      14
# grade_type              letter_group
# Name: 138384, dtype: object
# qualification       AdvancedHigher
# year                          2014
# Subject            Classical Greek
# NumberOfCentres                NaN
# gender                      female
# grade                          A-C
# NoOfStudents                   NaN
# grade_type            letter_group
# Name: 138387, dtype: object
# qualification       AdvancedHigher
# year                          2014
# Subject            Classical Greek
# NumberOfCentres                NaN
# gender                        male
# grade                          A-C
# NoOfStudents                   NaN
# grade_type            letter_group
# Name: 138386, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Classical Studies
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      26
# grade_type              letter_group
# Name: 138389, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Classical Studies
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                      23
# grade_type              letter_group
# Name: 138388, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Computing
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   54
# grade_type           letter_group
# Name: 138391, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Computing
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  318
# grade_type           letter_group
# Name: 138390, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Drama
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  211
# grade_type           letter_group
# Name: 138393, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Drama
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   81
# grade_type           letter_group
# Name: 138392, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Economics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   14
# grade_type           letter_group
# Name: 138395, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Economics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   51
# grade_type           letter_group
# Name: 138394, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   English
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                 1090
# grade_type           letter_group
# Name: 138397, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   English
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  384
# grade_type           letter_group
# Name: 138396, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                    French
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  386
# grade_type           letter_group
# Name: 138399, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                    French
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  116
# grade_type           letter_group
# Name: 138398, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      12
# grade_type              letter_group
# Name: 138401, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                       7
# grade_type              letter_group
# Name: 138400, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Geography
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  439
# grade_type           letter_group
# Name: 138405, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                 Geography
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  349
# grade_type           letter_group
# Name: 138404, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                    German
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   88
# grade_type           letter_group
# Name: 138407, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                    German
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   34
# grade_type           letter_group
# Name: 138406, dtype: object
# qualification             AdvancedHigher
# year                                2014
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                            female
# grade                                A-C
# NoOfStudents                         294
# grade_type                  letter_group
# Name: 138409, dtype: object
# qualification             AdvancedHigher
# year                                2014
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                              male
# grade                                A-C
# NoOfStudents                         572
# grade_type                  letter_group
# Name: 138408, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                  Gàidhlig
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   19
# grade_type           letter_group
# Name: 138403, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                  Gàidhlig
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                    7
# grade_type           letter_group
# Name: 138402, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   History
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  720
# grade_type           letter_group
# Name: 138411, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   History
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  478
# grade_type           letter_group
# Name: 138410, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2014
# Subject            Home Economics: Health and Food Technology
# NumberOfCentres                                           NaN
# gender                                                 female
# grade                                                     A-C
# NoOfStudents                                               29
# grade_type                                       letter_group
# Name: 138413, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2014
# Subject            Home Economics: Health and Food Technology
# NumberOfCentres                                           NaN
# gender                                                   male
# grade                                                     A-C
# NoOfStudents                                                3
# grade_type                                       letter_group
# Name: 138412, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Information Systems
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                        13
# grade_type                letter_group
# Name: 138415, dtype: object
# qualification           AdvancedHigher
# year                              2014
# Subject            Information Systems
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                        14
# grade_type                letter_group
# Name: 138414, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Italian
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   22
# grade_type           letter_group
# Name: 138417, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Italian
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   10
# grade_type           letter_group
# Name: 138416, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Latin
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   15
# grade_type           letter_group
# Name: 138419, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Latin
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   11
# grade_type           letter_group
# Name: 138418, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject               Mathematics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  982
# grade_type           letter_group
# Name: 138421, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject               Mathematics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                 1430
# grade_type           letter_group
# Name: 138420, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  468
# grade_type           letter_group
# Name: 138423, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  218
# grade_type           letter_group
# Name: 138422, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Music
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  784
# grade_type           letter_group
# Name: 138425, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                     Music
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  668
# grade_type           letter_group
# Name: 138424, dtype: object
# qualification          AdvancedHigher
# year                             2014
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                         female
# grade                             A-C
# NoOfStudents                       40
# grade_type               letter_group
# Name: 138427, dtype: object
# qualification          AdvancedHigher
# year                             2014
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                           male
# grade                             A-C
# NoOfStudents                       58
# grade_type               letter_group
# Name: 138426, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Physics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  331
# grade_type           letter_group
# Name: 138429, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Physics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                 1133
# grade_type           letter_group
# Name: 138428, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Physics (Revised)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      12
# grade_type              letter_group
# Name: 138431, dtype: object
# qualification         AdvancedHigher
# year                            2014
# Subject            Physics (Revised)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                      80
# grade_type              letter_group
# Name: 138430, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject            Product Design
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   20
# grade_type           letter_group
# Name: 138433, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject            Product Design
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   20
# grade_type           letter_group
# Name: 138432, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2014
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                 female
# grade                                                     A-C
# NoOfStudents                                              144
# grade_type                                       letter_group
# Name: 138435, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2014
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                   male
# grade                                                     A-C
# NoOfStudents                                               45
# grade_type                                       letter_group
# Name: 138434, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Spanish
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  139
# grade_type           letter_group
# Name: 138437, dtype: object
# qualification      AdvancedHigher
# year                         2014
# Subject                   Spanish
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   58
# grade_type           letter_group
# Name: 138436, dtype: object
# qualification             AdvancedHigher
# year                                2014
# Subject            Technological Studies
# NumberOfCentres                      NaN
# gender                            female
# grade                                A-C
# NoOfStudents                           5
# grade_type                  letter_group
# Name: 138439, dtype: object
# qualification             AdvancedHigher
# year                                2014
# Subject            Technological Studies
# NumberOfCentres                      NaN
# gender                              male
# grade                                A-C
# NoOfStudents                          55
# grade_type                  letter_group
# Name: 138438, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                Accounting
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   10
# grade_type           letter_group
# Name: 138683, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                Accounting
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   17
# grade_type           letter_group
# Name: 138682, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Applied Mathematics
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                        95
# grade_type                letter_group
# Name: 138685, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Applied Mathematics
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                       235
# grade_type                letter_group
# Name: 138684, dtype: object
# qualification              AdvancedHigher
# year                                 2015
# Subject            Art and Design: Design
# NumberOfCentres                       NaN
# gender                             female
# grade                                 A-C
# NoOfStudents                          418
# grade_type                   letter_group
# Name: 138687, dtype: object
# qualification              AdvancedHigher
# year                                 2015
# Subject            Art and Design: Design
# NumberOfCentres                       NaN
# gender                               male
# grade                                 A-C
# NoOfStudents                           82
# grade_type                   letter_group
# Name: 138686, dtype: object
# qualification                  AdvancedHigher
# year                                     2015
# Subject            Art and Design: Expressive
# NumberOfCentres                           NaN
# gender                                 female
# grade                                     A-C
# NoOfStudents                              669
# grade_type                       letter_group
# Name: 138689, dtype: object
# qualification                  AdvancedHigher
# year                                     2015
# Subject            Art and Design: Expressive
# NumberOfCentres                           NaN
# gender                                   male
# grade                                     A-C
# NoOfStudents                              123
# grade_type                       letter_group
# Name: 138688, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Biology
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                 1264
# grade_type           letter_group
# Name: 138691, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Biology
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  610
# grade_type           letter_group
# Name: 138690, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Biology (Revised)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      14
# grade_type              letter_group
# Name: 138693, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Biology (Revised)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                     NaN
# grade_type              letter_group
# Name: 138692, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Business Management
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                       122
# grade_type                letter_group
# Name: 138695, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Business Management
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                        60
# grade_type                letter_group
# Name: 138694, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Chemistry
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  975
# grade_type           letter_group
# Name: 138697, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Chemistry
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  993
# grade_type           letter_group
# Name: 138696, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Chemistry (Revised)
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                       148
# grade_type                letter_group
# Name: 138699, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Chemistry (Revised)
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                       130
# grade_type                letter_group
# Name: 138698, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Chinese Languages
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      14
# grade_type              letter_group
# Name: 138701, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Chinese Languages
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                      12
# grade_type              letter_group
# Name: 138700, dtype: object
# qualification       AdvancedHigher
# year                          2015
# Subject            Classical Greek
# NumberOfCentres                NaN
# gender                      female
# grade                          A-C
# NoOfStudents                   NaN
# grade_type            letter_group
# Name: 138703, dtype: object
# qualification       AdvancedHigher
# year                          2015
# Subject            Classical Greek
# NumberOfCentres                NaN
# gender                        male
# grade                          A-C
# NoOfStudents                   NaN
# grade_type            letter_group
# Name: 138702, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Classical Studies
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      36
# grade_type              letter_group
# Name: 138705, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Classical Studies
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                      21
# grade_type              letter_group
# Name: 138704, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Computing
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   59
# grade_type           letter_group
# Name: 138707, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Computing
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  372
# grade_type           letter_group
# Name: 138706, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Drama
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  224
# grade_type           letter_group
# Name: 138709, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Drama
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   80
# grade_type           letter_group
# Name: 138708, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Economics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   19
# grade_type           letter_group
# Name: 138711, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Economics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   57
# grade_type           letter_group
# Name: 138710, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   English
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                 1031
# grade_type           letter_group
# Name: 138713, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   English
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  406
# grade_type           letter_group
# Name: 138712, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                    French
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  429
# grade_type           letter_group
# Name: 138715, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                    French
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  123
# grade_type           letter_group
# Name: 138714, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      21
# grade_type              letter_group
# Name: 138717, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                       4
# grade_type              letter_group
# Name: 138716, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Geography
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  501
# grade_type           letter_group
# Name: 138721, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                 Geography
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  338
# grade_type           letter_group
# Name: 138720, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                    German
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   58
# grade_type           letter_group
# Name: 138723, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                    German
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   35
# grade_type           letter_group
# Name: 138722, dtype: object
# qualification             AdvancedHigher
# year                                2015
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                            female
# grade                                A-C
# NoOfStudents                         271
# grade_type                  letter_group
# Name: 138725, dtype: object
# qualification             AdvancedHigher
# year                                2015
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                              male
# grade                                A-C
# NoOfStudents                         538
# grade_type                  letter_group
# Name: 138724, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                  Gàidhlig
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   30
# grade_type           letter_group
# Name: 138719, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                  Gàidhlig
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                    7
# grade_type           letter_group
# Name: 138718, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   History
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  782
# grade_type           letter_group
# Name: 138727, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   History
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  527
# grade_type           letter_group
# Name: 138726, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2015
# Subject            Home Economics: Health and Food Technology
# NumberOfCentres                                           NaN
# gender                                                 female
# grade                                                     A-C
# NoOfStudents                                               18
# grade_type                                       letter_group
# Name: 138729, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2015
# Subject            Home Economics: Health and Food Technology
# NumberOfCentres                                           NaN
# gender                                                   male
# grade                                                     A-C
# NoOfStudents                                              NaN
# grade_type                                       letter_group
# Name: 138728, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Information Systems
# NumberOfCentres                    NaN
# gender                          female
# grade                              A-C
# NoOfStudents                        10
# grade_type                letter_group
# Name: 138731, dtype: object
# qualification           AdvancedHigher
# year                              2015
# Subject            Information Systems
# NumberOfCentres                    NaN
# gender                            male
# grade                              A-C
# NoOfStudents                        18
# grade_type                letter_group
# Name: 138730, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Italian
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   21
# grade_type           letter_group
# Name: 138733, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Italian
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                    8
# grade_type           letter_group
# Name: 138732, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Latin
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   26
# grade_type           letter_group
# Name: 138735, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Latin
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   10
# grade_type           letter_group
# Name: 138734, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject               Mathematics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  943
# grade_type           letter_group
# Name: 138737, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject               Mathematics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                 1562
# grade_type           letter_group
# Name: 138736, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  514
# grade_type           letter_group
# Name: 138739, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  193
# grade_type           letter_group
# Name: 138738, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Music
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  823
# grade_type           letter_group
# Name: 138741, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                     Music
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                  640
# grade_type           letter_group
# Name: 138740, dtype: object
# qualification          AdvancedHigher
# year                             2015
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                         female
# grade                             A-C
# NoOfStudents                       58
# grade_type               letter_group
# Name: 138743, dtype: object
# qualification          AdvancedHigher
# year                             2015
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                           male
# grade                             A-C
# NoOfStudents                       44
# grade_type               letter_group
# Name: 138742, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Physics
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  299
# grade_type           letter_group
# Name: 138745, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Physics
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                 1137
# grade_type           letter_group
# Name: 138744, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Physics (Revised)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      28
# grade_type              letter_group
# Name: 138747, dtype: object
# qualification         AdvancedHigher
# year                            2015
# Subject            Physics (Revised)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                     114
# grade_type              letter_group
# Name: 138746, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject            Product Design
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                   13
# grade_type           letter_group
# Name: 138749, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject            Product Design
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   10
# grade_type           letter_group
# Name: 138748, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2015
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                 female
# grade                                                     A-C
# NoOfStudents                                              149
# grade_type                                       letter_group
# Name: 138751, dtype: object
# qualification                                  AdvancedHigher
# year                                                     2015
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                   male
# grade                                                     A-C
# NoOfStudents                                               58
# grade_type                                       letter_group
# Name: 138750, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Spanish
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                  196
# grade_type           letter_group
# Name: 138753, dtype: object
# qualification      AdvancedHigher
# year                         2015
# Subject                   Spanish
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                   66
# grade_type           letter_group
# Name: 138752, dtype: object
# qualification             AdvancedHigher
# year                                2015
# Subject            Technological Studies
# ...
# grade_type                           letter_group
# Name: 139026, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                  French
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents               1795
# grade_type         letter_group
# Name: 139029, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                  French
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                619
# grade_type         letter_group
# Name: 139028, dtype: object
# qualification              NewHigher
# year                            2015
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                        female
# grade                            A-C
# NoOfStudents                      31
# grade_type              letter_group
# Name: 139031, dtype: object
# qualification              NewHigher
# year                            2015
# Subject            Gaelic (Learners)
# NumberOfCentres                  NaN
# gender                          male
# grade                            A-C
# NoOfStudents                       6
# grade_type              letter_group
# Name: 139030, dtype: object
# qualification         NewHigher
# year                       2015
# Subject               Geography
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents               1558
# grade_type         letter_group
# Name: 139035, dtype: object
# qualification         NewHigher
# year                       2015
# Subject               Geography
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents               1288
# grade_type         letter_group
# Name: 139034, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                  German
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                364
# grade_type         letter_group
# Name: 139037, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                  German
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                167
# grade_type         letter_group
# Name: 139036, dtype: object
# qualification                  NewHigher
# year                                2015
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                            female
# grade                                A-C
# NoOfStudents                        1040
# grade_type                  letter_group
# Name: 139039, dtype: object
# qualification                  NewHigher
# year                                2015
# Subject            Graphic Communication
# NumberOfCentres                      NaN
# gender                              male
# grade                                A-C
# NoOfStudents                        2125
# grade_type                  letter_group
# Name: 139038, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                Gàidhlig
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 54
# grade_type         letter_group
# Name: 139033, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                Gàidhlig
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 18
# grade_type         letter_group
# Name: 139032, dtype: object
# qualification                       NewHigher
# year                                     2015
# Subject            Health and Food Technology
# NumberOfCentres                           NaN
# gender                                 female
# grade                                     A-C
# NoOfStudents                              607
# grade_type                       letter_group
# Name: 139041, dtype: object
# qualification                       NewHigher
# year                                     2015
# Subject            Health and Food Technology
# NumberOfCentres                           NaN
# gender                                   male
# grade                                     A-C
# NoOfStudents                               79
# grade_type                       letter_group
# Name: 139040, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 History
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents               3850
# grade_type         letter_group
# Name: 139043, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 History
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents               2360
# grade_type         letter_group
# Name: 139042, dtype: object
# qualification          NewHigher
# year                        2015
# Subject            Human Biology
# NumberOfCentres              NaN
# gender                    female
# grade                        A-C
# NoOfStudents                 814
# grade_type          letter_group
# Name: 139045, dtype: object
# qualification          NewHigher
# year                        2015
# Subject            Human Biology
# NumberOfCentres              NaN
# gender                      male
# grade                        A-C
# NoOfStudents                 366
# grade_type          letter_group
# Name: 139044, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Italian
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 77
# grade_type         letter_group
# Name: 139047, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Italian
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 27
# grade_type         letter_group
# Name: 139046, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Latin
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 89
# grade_type         letter_group
# Name: 139049, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Latin
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 70
# grade_type         letter_group
# Name: 139048, dtype: object
# qualification         NewHigher
# year                       2015
# Subject             Mathematics
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents               3483
# grade_type         letter_group
# Name: 139051, dtype: object
# qualification         NewHigher
# year                       2015
# Subject             Mathematics
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents               3720
# grade_type         letter_group
# Name: 139050, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Media
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                238
# grade_type         letter_group
# Name: 139053, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Media
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                158
# grade_type         letter_group
# Name: 139052, dtype: object
# qualification           NewHigher
# year                         2015
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                     female
# grade                         A-C
# NoOfStudents                 2175
# grade_type           letter_group
# Name: 139055, dtype: object
# qualification           NewHigher
# year                         2015
# Subject            Modern Studies
# NumberOfCentres               NaN
# gender                       male
# grade                         A-C
# NoOfStudents                 1172
# grade_type           letter_group
# Name: 139054, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Music
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents               2350
# grade_type         letter_group
# Name: 139057, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                   Music
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents               1754
# grade_type         letter_group
# Name: 139056, dtype: object
# qualification             NewHigher
# year                           2015
# Subject            Music Technology
# NumberOfCentres                 NaN
# gender                       female
# grade                           A-C
# NoOfStudents                     78
# grade_type             letter_group
# Name: 139059, dtype: object
# qualification             NewHigher
# year                           2015
# Subject            Music Technology
# NumberOfCentres                 NaN
# gender                         male
# grade                           A-C
# NoOfStudents                    167
# grade_type             letter_group
# Name: 139058, dtype: object
# qualification         NewHigher
# year                       2015
# Subject              Philosophy
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                233
# grade_type         letter_group
# Name: 139061, dtype: object
# qualification         NewHigher
# year                       2015
# Subject              Philosophy
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                128
# grade_type         letter_group
# Name: 139060, dtype: object
# qualification         NewHigher
# year                       2015
# Subject             Photography
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                642
# grade_type         letter_group
# Name: 139063, dtype: object
# qualification         NewHigher
# year                       2015
# Subject             Photography
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                252
# grade_type         letter_group
# Name: 139062, dtype: object
# qualification               NewHigher
# year                             2015
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                         female
# grade                             A-C
# NoOfStudents                     1806
# grade_type               letter_group
# Name: 139065, dtype: object
# qualification               NewHigher
# year                             2015
# Subject            Physical Education
# NumberOfCentres                   NaN
# gender                           male
# grade                             A-C
# NoOfStudents                     4080
# grade_type               letter_group
# Name: 139064, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Physics
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                800
# grade_type         letter_group
# Name: 139067, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Physics
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents               1767
# grade_type         letter_group
# Name: 139066, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                Politics
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 85
# grade_type         letter_group
# Name: 139069, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                Politics
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 63
# grade_type         letter_group
# Name: 139068, dtype: object
# qualification         NewHigher
# year                       2015
# Subject              Psychology
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                254
# grade_type         letter_group
# Name: 139071, dtype: object
# qualification         NewHigher
# year                       2015
# Subject              Psychology
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 72
# grade_type         letter_group
# Name: 139070, dtype: object
# qualification                                       NewHigher
# year                                                     2015
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                 female
# grade                                                     A-C
# NoOfStudents                                             1394
# grade_type                                       letter_group
# Name: 139073, dtype: object
# qualification                                       NewHigher
# year                                                     2015
# Subject            Religious, Moral and Philosophical Studies
# NumberOfCentres                                           NaN
# gender                                                   male
# grade                                                     A-C
# NoOfStudents                                              442
# grade_type                                       letter_group
# Name: 139072, dtype: object
# qualification         NewHigher
# year                       2015
# Subject               Sociology
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 82
# grade_type         letter_group
# Name: 139075, dtype: object
# qualification         NewHigher
# year                       2015
# Subject               Sociology
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 19
# grade_type         letter_group
# Name: 139074, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Spanish
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                932
# grade_type         letter_group
# Name: 139077, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                 Spanish
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                354
# grade_type         letter_group
# Name: 139076, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                    Urdu
# NumberOfCentres             NaN
# gender                   female
# grade                       A-C
# NoOfStudents                 32
# grade_type         letter_group
# Name: 139079, dtype: object
# qualification         NewHigher
# year                       2015
# Subject                    Urdu
# NumberOfCentres             NaN
# gender                     male
# grade                       A-C
# NoOfStudents                 16
# grade_type         letter_group
# Name: 139078, dtype: object

# %% [markdown]
# #### Exploring the grades further below

# %%
df3.loc[(df3['qualification'] == 'AdvancedHigher') & (df3['year'] == '2004') & (df3['Subject'] == 'Music')]
# Out:
#         qualification  year Subject  NumberOfCentres  gender       grade  \
# 64071  AdvancedHigher  2004   Music            266.0    male     Entries
# 64072  AdvancedHigher  2004   Music            266.0    male  percentage
# 64073  AdvancedHigher  2004   Music            266.0    male           A
# 64074  AdvancedHigher  2004   Music            266.0    male           B
# 64075  AdvancedHigher  2004   Music            266.0    male           C
# 64076  AdvancedHigher  2004   Music            266.0    male      Passes
# 64077  AdvancedHigher  2004   Music            266.0    male        COMP
# 64078  AdvancedHigher  2004   Music            266.0  female     Entries
# 64079  AdvancedHigher  2004   Music            266.0  female  percentage
# 64080  AdvancedHigher  2004   Music            266.0  female           A
# 64081  AdvancedHigher  2004   Music            266.0  female           B
# 64082  AdvancedHigher  2004   Music            266.0  female           C
# 64083  AdvancedHigher  2004   Music            266.0  female      Passes
# 64084  AdvancedHigher  2004   Music            266.0  female        COMP
# 64085  AdvancedHigher  2004   Music            266.0     all     Entries
# 64086  AdvancedHigher  2004   Music            266.0     all           A
# 64087  AdvancedHigher  2004   Music            266.0     all           B
# 64088  AdvancedHigher  2004   Music            266.0     all           C
# 64089  AdvancedHigher  2004   Music            266.0     all      Passes
# 64090  AdvancedHigher  2004   Music            266.0     all        COMP
#
#        NoOfStudents
# 64071         384.0
# 64072          43.0
# 64073         182.0
# 64074         112.0
# 64075          60.0
# 64076         354.0
# 64077           7.0
# 64078         508.0
# 64079          57.0
# 64080         270.0
# 64081         139.0
# 64082          63.0
# 64083         472.0
# 64084          15.0
# 64085         892.0
# 64086         452.0
# 64087         251.0
# 64088         123.0
# 64089         826.0
# 64090          22.0

# %%
df3.loc[(df3['qualification'] == 'OrdinaryGrade') & (df3['Subject'] == 'Biology') & (df3['year'] == '1993')]
# Out:
#        qualification  year  Subject  NumberOfCentres  gender       grade  \
# 24486  OrdinaryGrade  1993  Biology             12.0    male     Entries
# 24487  OrdinaryGrade  1993  Biology             12.0    male  percentage
# 24488  OrdinaryGrade  1993  Biology             12.0    male           1
# 24489  OrdinaryGrade  1993  Biology             12.0    male           2
# 24490  OrdinaryGrade  1993  Biology             12.0    male           3
# 24491  OrdinaryGrade  1993  Biology             12.0    male           4
# 24492  OrdinaryGrade  1993  Biology             12.0    male           5
# 24493  OrdinaryGrade  1993  Biology             12.0  female     Entries
# 24494  OrdinaryGrade  1993  Biology             12.0  female  percentage
# 24495  OrdinaryGrade  1993  Biology             12.0  female           1
# 24496  OrdinaryGrade  1993  Biology             12.0  female           2
# 24497  OrdinaryGrade  1993  Biology             12.0  female           3
# 24498  OrdinaryGrade  1993  Biology             12.0  female           4
# 24499  OrdinaryGrade  1993  Biology             12.0  female           5
# 24500  OrdinaryGrade  1993  Biology             12.0     all     Entries
# 24501  OrdinaryGrade  1993  Biology             12.0     all           1
# 24502  OrdinaryGrade  1993  Biology             12.0     all           2
# 24503  OrdinaryGrade  1993  Biology             12.0     all           3
# 24504  OrdinaryGrade  1993  Biology             12.0     all           4
# 24505  OrdinaryGrade  1993  Biology             12.0     all           5
#
#        NoOfStudents
# 24486           9.0
# 24487           0.0
# 24488           NaN
# 24489           NaN
# 24490           2.0
# 24491           2.0
# 24492           3.0
# 24493           9.0
# 24494           0.0
# 24495           NaN
# 24496           3.0
# 24497           2.0
# 24498           3.0
# 24499           1.0
# 24500          18.0
# 24501           NaN
# 24502           3.0
# 24503           4.0
# 24504           5.0
# 24505           4.0

# %%
df3.loc[(df3['qualification'] == 'National5') & (~df3['NoOfStudents'].isnull())]
# Out:
#        qualification  year     Subject  NumberOfCentres  gender    grade  \
# 124203     National5  2014  Accounting              NaN     all  Entries
# 124204     National5  2014  Accounting              NaN    male  Entries
# 124205     National5  2014  Accounting              NaN  female  Entries
# 124206     National5  2014  Accounting              NaN     all        A
# 124207     National5  2014  Accounting              NaN     all        B
# ...              ...   ...         ...              ...     ...      ...
# 155880     National5  2021        Urdu              NaN     all        A
# 155881     National5  2021        Urdu              NaN     all      A-B
# 155882     National5  2021        Urdu              NaN     all      A-C
# 155883     National5  2021        Urdu              NaN     all      A-D
# 155884     National5  2021        Urdu              NaN     all  NoAward
#
#         NoOfStudents
# 124203         777.0
# 124204         350.0
# 124205         427.0
# 124206         381.0
# 124207         148.0
# ...              ...
# 155880          52.0
# 155881          64.0
# 155882          66.0
# 155883          66.0
# 155884           0.0
#
# [4884 rows x 7 columns]

# %%
df3.loc[(df3['qualification'] == 'National5') & (df3['Subject'] == 'Urdu')]
# Out:
#        qualification  year Subject  NumberOfCentres  gender    grade  \
# 124720     National5  2014    Urdu              NaN     all  Entries
# 124721     National5  2014    Urdu              NaN    male  Entries
# 124722     National5  2014    Urdu              NaN  female  Entries
# 124723     National5  2014    Urdu              NaN     all        A
# 124724     National5  2014    Urdu              NaN     all        B
# 124725     National5  2014    Urdu              NaN     all        C
# 124726     National5  2014    Urdu              NaN     all        D
# 124727     National5  2014    Urdu              NaN    male        A
# 124728     National5  2014    Urdu              NaN  female        A
# 124729     National5  2014    Urdu              NaN    male     Pass
# 124730     National5  2014    Urdu              NaN  female     Pass
# 129734     National5  2015    Urdu              NaN     all  Entries
# 129735     National5  2015    Urdu              NaN    male  Entries
# 129736     National5  2015    Urdu              NaN  female  Entries
# 129737     National5  2015    Urdu              NaN     all        A
# 129738     National5  2015    Urdu              NaN     all        B
# 129739     National5  2015    Urdu              NaN     all        C
# 129740     National5  2015    Urdu              NaN     all        D
# 129741     National5  2015    Urdu              NaN    male        A
# 129742     National5  2015    Urdu              NaN  female        A
# 129743     National5  2015    Urdu              NaN    male     Pass
# 129744     National5  2015    Urdu              NaN  female     Pass
# 133850     National5  2016    Urdu              NaN     all  Entries
# 133851     National5  2016    Urdu              NaN    male  Entries
# 133852     National5  2016    Urdu              NaN  female  Entries
# 133853     National5  2016    Urdu              NaN     all        A
# 133854     National5  2016    Urdu              NaN     all        B
# 133855     National5  2016    Urdu              NaN     all        C
# 133856     National5  2016    Urdu              NaN     all        D
# 133857     National5  2016    Urdu              NaN    male        A
# 133858     National5  2016    Urdu              NaN  female        A
# 133859     National5  2016    Urdu              NaN    male     Pass
# 133860     National5  2016    Urdu              NaN  female     Pass
# 137442     National5  2017    Urdu              NaN     all  Entries
# 137443     National5  2017    Urdu              NaN    male  Entries
# 137444     National5  2017    Urdu              NaN  female  Entries
# 137445     National5  2017    Urdu              NaN     all        A
# 137446     National5  2017    Urdu              NaN     all        B
# 137447     National5  2017    Urdu              NaN     all        C
# 137448     National5  2017    Urdu              NaN     all        D
# 137449     National5  2017    Urdu              NaN    male        A
# 137450     National5  2017    Urdu              NaN  female        A
# 137451     National5  2017    Urdu              NaN    male     Pass
# 137452     National5  2017    Urdu              NaN  female     Pass
# 141031     National5  2018    Urdu              NaN     all  Entries
# 141032     National5  2018    Urdu              NaN    male  Entries
# 141033     National5  2018    Urdu              NaN  female  Entries
# 141034     National5  2018    Urdu              NaN     all        A
# 141035     National5  2018    Urdu              NaN     all        B
# 141036     National5  2018    Urdu              NaN     all        C
# 141037     National5  2018    Urdu              NaN     all        D
# 141038     National5  2018    Urdu              NaN    male        A
# 141039     National5  2018    Urdu              NaN  female        A
# 141040     National5  2018    Urdu              NaN    male     Pass
# 141041     National5  2018    Urdu              NaN  female     Pass
# 145638     National5  2019    Urdu              NaN     all  Entries
# 145639     National5  2019    Urdu              NaN    male  Entries
# 145640     National5  2019    Urdu              NaN  female  Entries
# 145641     National5  2019    Urdu              NaN     all        A
# 145642     National5  2019    Urdu              NaN     all        B
# 145643     National5  2019    Urdu              NaN     all        C
# 145644     National5  2019    Urdu              NaN     all        D
# 145645     National5  2019    Urdu              NaN    male        A
# 145646     National5  2019    Urdu              NaN  female        A
# 145647     National5  2019    Urdu              NaN    male     Pass
# 145648     National5  2019    Urdu              NaN  female     Pass
# 150749     National5  2020    Urdu              NaN    male  Entries
# 150750     National5  2020    Urdu              NaN    male        A
# 150751     National5  2020    Urdu              NaN    male      A-B
# 150752     National5  2020    Urdu              NaN    male      A-C
# 150753     National5  2020    Urdu              NaN    male      A-D
# 150754     National5  2020    Urdu              NaN    male  NoAward
# 150755     National5  2020    Urdu              NaN  female  Entries
# 150756     National5  2020    Urdu              NaN  female        A
# 150757     National5  2020    Urdu              NaN  female      A-B
# 150758     National5  2020    Urdu              NaN  female      A-C
# 150759     National5  2020    Urdu              NaN  female      A-D
# 150760     National5  2020    Urdu              NaN  female  NoAward
# 150761     National5  2020    Urdu              NaN     all  Entries
# 150762     National5  2020    Urdu              NaN     all        A
# 150763     National5  2020    Urdu              NaN     all      A-B
# 150764     National5  2020    Urdu              NaN     all      A-C
# 150765     National5  2020    Urdu              NaN     all      A-D
# 150766     National5  2020    Urdu              NaN     all  NoAward
# 155867     National5  2021    Urdu              NaN    male  Entries
# 155868     National5  2021    Urdu              NaN    male        A
# 155869     National5  2021    Urdu              NaN    male      A-B
# 155870     National5  2021    Urdu              NaN    male      A-C
# 155871     National5  2021    Urdu              NaN    male      A-D
# 155872     National5  2021    Urdu              NaN    male  NoAward
# 155873     National5  2021    Urdu              NaN  female  Entries
# 155874     National5  2021    Urdu              NaN  female        A
# 155875     National5  2021    Urdu              NaN  female      A-B
# 155876     National5  2021    Urdu              NaN  female      A-C
# 155877     National5  2021    Urdu              NaN  female      A-D
# 155878     National5  2021    Urdu              NaN  female  NoAward
# 155879     National5  2021    Urdu              NaN     all  Entries
# 155880     National5  2021    Urdu              NaN     all        A
# 155881     National5  2021    Urdu              NaN     all      A-B
# 155882     National5  2021    Urdu              NaN     all      A-C
# 155883     National5  2021    Urdu              NaN     all      A-D
# 155884     National5  2021    Urdu              NaN     all  NoAward
#
#         NoOfStudents
# 124720          42.0
# 124721          17.0
# 124722          25.0
# 124723          34.0
# 124724           3.0
# 124725           5.0
# 124726           0.0
# 124727          12.0
# 124728          22.0
# 124729          17.0
# 124730          25.0
# 129734          49.0
# 129735          18.0
# 129736          31.0
# 129737          37.0
# 129738           3.0
# 129739           4.0
# 129740           1.0
# 129741          11.0
# 129742          26.0
# 129743          15.0
# 129744          29.0
# 133850          62.0
# 133851          26.0
# 133852          36.0
# 133853          45.0
# 133854           6.0
# 133855           6.0
# 133856           3.0
# 133857          20.0
# 133858          25.0
# 133859          24.0
# 133860          33.0
# 137442          74.0
# 137443          33.0
# 137444          41.0
# 137445          50.0
# 137446          11.0
# 137447           7.0
# 137448           3.0
# 137449          21.0
# 137450          29.0
# 137451          29.0
# 137452          39.0
# 141031          45.0
# 141032          21.0
# 141033          24.0
# 141034          35.0
# 141035           5.0
# 141036           5.0
# 141037           0.0
# 141038          16.0
# 141039          19.0
# 141040          21.0
# 141041          24.0
# 145638          74.0
# 145639          25.0
# 145640          49.0
# 145641          64.0
# 145642           8.0
# 145643           1.0
# 145644           1.0
# 145645          21.0
# 145646          43.0
# 145647          25.0
# 145648          48.0
# 150749          36.0
# 150750          34.0
# 150751          35.0
# 150752          36.0
# 150753          36.0
# 150754           0.0
# 150755          51.0
# 150756          44.0
# 150757          50.0
# 150758          51.0
# 150759          51.0
# 150760           0.0
# 150761          87.0
# 150762          67.0
# 150763          82.0
# 150764          85.0
# 150765          86.0
# 150766           1.0
# 155867          24.0
# 155868          15.0
# 155869          23.0
# 155870          24.0
# 155871          24.0
# 155872           0.0
# 155873          42.0
# 155874          37.0
# 155875          41.0
# 155876          42.0
# 155877          42.0
# 155878           0.0
# 155879          66.0
# 155880          52.0
# 155881          64.0
# 155882          66.0
# 155883          66.0
# 155884           0.0

# %%
df3.loc[(df3['year'] == '2017') & (df3['qualification'] == 'Higher')]
# Out:
#        qualification  year     Subject  NumberOfCentres  gender    grade  \
# 135843        Higher  2017  Accounting              NaN     all  Entries
# 135844        Higher  2017  Accounting              NaN    male  Entries
# 135845        Higher  2017  Accounting              NaN  female  Entries
# 135846        Higher  2017  Accounting              NaN    male        A
# 135847        Higher  2017  Accounting              NaN  female        A
# ...              ...   ...         ...              ...     ...      ...
# 136344        Higher  2017        Urdu              NaN  female      A-C
# 136345        Higher  2017        Urdu              NaN     all        A
# 136346        Higher  2017        Urdu              NaN     all        B
# 136347        Higher  2017        Urdu              NaN     all        C
# 136348        Higher  2017        Urdu              NaN     all        D
#
#         NoOfStudents
# 135843        1319.0
# 135844         725.0
# 135845         594.0
# 135846         276.0
# 135847         220.0
# ...              ...
# 136344          68.0
# 136345          84.0
# 136346          11.0
# 136347           5.0
# 136348           3.0
#
# [506 rows x 7 columns]

# %% [markdown]
# #### Create a subset of sqa_data with qualifications from 2000 onwards

# %%
df_subset2000_21 = df3.loc[(df3['year'] == '2000') | (df3['year'] == '2001') | (df3['year'] == '2002') | (df3['year'] == '2003') | 
                           (df3['year'] == '2004') | (df3['year'] == '2005') | (df3['year'] == '2006') | (df3['year'] == '2007') | 
                          (df3['year'] == '2008') | (df3['year'] == '2009') | (df3['year'] == '2010') | (df3['year'] == '2011') | 
                          (df3['year'] == '2012') | (df3['year'] == '2013') | 
                           (df3['year'] == '2014') | (df3['year'] == '2015') | (df3['year'] == '2016') | (df3['year'] == '2017') | 
                          (df3['year'] == '2018') | (df3['year'] == '2019') | (df3['year'] == '2020') | (df3['year'] == '2021')]

# %%
df_subset_quali = df3.loc[(df3['qualification'] == 'Higher') | (df3['qualification'] == 'Intermediate1') |
                           (df3['qualification'] == 'Intermediate2') | (df3['qualification'] == 'NewHigher') |
                           (df3['qualification'] == 'AdvancedHigher') | (df3['qualification'] == 'National2') | 
                           (df3['qualification'] == 'National3')| (df3['qualification'] == 'National4') |
                           (df3['qualification'] == 'National5') | (df3['qualification'] == 'NationalCertificate') |
                           (df3['qualification'] == 'NationalProgressionAward')]

# %%
df_subset_quali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117932 entries, 500 to 159667
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   qualification    117932 non-null  object
#  1   year             117932 non-null  object
#  2   Subject          117932 non-null  object
#  3   NumberOfCentres  78342 non-null   float64
#  4   gender           117932 non-null  object
#  5   grade            117932 non-null  object
#  6   NoOfStudents     96274 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 7.2+ MB

# %%
df_subset2000_21['year'].unique()
# Out:
# array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021'], dtype=object)

# %%
df_subset_quali['grade'].unique()
# Out:
# array(['Entries', 'A', 'B', 'C', 'Passes', 'D', 'percentage', 'Comp',
#        'COMP', 'PassesesInUngradedCourses', 'PassesUngraded',
#        'PassesUngradedCourses', 'A-C', 'Pass', 'Attainment', 'SCQF3',
#        'SCQF4', 'SCQF5', 'SCQF6', 'SCQF2', '3', 'NoAward', 'A-B', 'A-D*',
#        'A-D'], dtype=object)

# %%
df_subset_quali.loc[(df_subset_quali['qualification'] == 'Higher') & (df_subset_quali['Subject'] == 'Accounting') & (df_subset_quali['year'] == '2014') ]
# Out:
#        qualification  year     Subject  NumberOfCentres  gender    grade  \
# 121816        Higher  2014  Accounting              NaN     all  Entries
# 121817        Higher  2014  Accounting              NaN    male  Entries
# 121818        Higher  2014  Accounting              NaN  female  Entries
# 121819        Higher  2014  Accounting              NaN    male        A
# 121820        Higher  2014  Accounting              NaN  female        A
# 121821        Higher  2014  Accounting              NaN    male      A-C
# 121822        Higher  2014  Accounting              NaN  female      A-C
# 121823        Higher  2014  Accounting              NaN     all        A
# 121824        Higher  2014  Accounting              NaN     all        B
# 121825        Higher  2014  Accounting              NaN     all        C
# 121826        Higher  2014  Accounting              NaN     all        D
#
#         NoOfStudents
# 121816        1277.0
# 121817         638.0
# 121818         638.0
# 121819         217.0
# 121820         211.0
# 121821         447.0
# 121822         447.0
# 121823         434.0
# 121824         255.0
# 121825         217.0
# 121826          77.0
